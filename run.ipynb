# %%
# %run generate.py --width 128 --height 64 --length 6 --symbols symbols_without_space.txt --count 100000 --output-dir training_data
# Out:
# Generating captchas with symbol set {!"#$%&()*+,/-:<=>?@[\]^abcdefghijklmnopqrstuvwxyz|~}
# Creating output directory training_data_test1
# Finished generating captchas with symbol set {!"#$%&()*+,/-:<=>?@[\]^abcdefghijklmnopqrstuvwxyz|~}

# %%
# %run generate.py --width 128 --height 64 --length 6 --symbols symbols_without_space.txt --count 10000 --output-dir validation_data
# Out:
# Generating captchas with symbol set {!"#$%&()*+,/-:<=>?@[\]^abcdefghijklmnopqrstuvwxyz|~}
# Creating output directory validation_data
# Finished generating captchas with symbol set {!"#$%&()*+,/-:<=>?@[\]^abcdefghijklmnopqrstuvwxyz|~}

# %%
# %run train.py --width 128 --height 64 --length 6 --symbols symbols_with_space.txt --batch-size 64 --epochs 50 --output-model project2 --train-dataset training_data --validate-dataset validation_data
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 64, 128, 1)] 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 128, 32)  320         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 128, 32)  128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 128, 32)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# %run convert.py --model-name project2
# Out:
# WARNING:tensorflow:From /Users/hughj/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/hughj/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /var/folders/bn/shqf5bxd2dndrz7xgw11xng80000gn/T/tmpsu81voig/assets
# Pushing project2.tflite to GitHub
# Finished pushing project2.tflife to GitHub

# %%
# %run classify_tflite.py --model-name project2 --captcha-dir JORDANHU-project2rpi --output project2.csv --symbols symbols_with_space.txt
# Out:
# Classifying captchas with symbol set {!"#$%&()*+,/-:<=>?@[\]^ abcdefghijklmnopqrstuvwxyz|~}
# 0: Classified f4e05bfa6cf62894a3323abe686b358a17c293a7.png as )!][#
# 1: Classified 91449f86a10e562ee42bb7b3ad335e68f83a0676.png as lce~
# 2: Classified 056e1093a31be88587e6f829b23376abda297085.png as t
# 3: Classified 183cb211e0cbdd54860f4047160133dac45becdb.png as ?v
# 4: Classified 34c506eba56068af2001371861c4a05da615bcf4.png as g)i&
# 5: Classified 97024883aa76674b49ec6e8f41ee112a5338545f.png as tx
# 6: Classified 944c5f70fe2d311996c6fc9e6469f00a11081254.png as -#@@c~
# 7: Classified 4c0c338f66ff4d49007db6db7b04f71b065b78a3.png as t%v:z"
# 8: Classified 64ce6370009db55cdf21eeb8df40d5959cb6941f.png as vgz
# 9: Classified fa4602ca314a0ac55d7e6a6ebe6aaf6ca7e851b8.png as ^v>
# 10: Classified d4151de97b7cbeb09e9dddecb37e4574dff14d98.png as ti%$~
# 11: Classified 40ee02917e8f8fbae0e258d0dda05122b471ad9b.png as %%j
# 12: Classified 99f7d19ef382311fc6dfeccc1485a85812d280d8.png as l@#^!l
# ...

# %%
# %run accuracy_tflite.py --model-name project2 --validate-dataset validation_data --symbols symbols_with_space.txt
# Out:
# Accuracy: 0.3547246625241054

# %%
# %run analysis.py --model-name project2.h5 --validate-dataset validation_data --symbols symbols_with_space.txt
# Out:
#                   Model Analysis
#
# Character  Misclassified   Occurances     Weights
# !          1.45%           1.03%          1.57%
# "          1.74%           1.03%          1.87%
# #          1.45%           1.11%          1.45%
# $          1.80%           1.03%          1.94%
# %          1.16%           1.08%          1.19%
# &          0.99%           1.06%          1.03%
# (          1.45%           1.06%          1.52%
# )          1.39%           1.11%          1.39%
# *          2.61%           1.03%          2.81%
# +          1.57%           1.04%          1.68%
# ,          7.38%           1.09%          7.52%
# /          0.00%           0.00%          0.00%
# -          3.43%           1.00%          3.82%
# :          1.10%           1.03%          1.19%
# <          1.57%           1.09%          1.59%
# =          2.44%           1.15%          2.36%
# >          1.22%           1.03%          1.32%
# ?          1.45%           1.08%          1.49%
# ...

# %%
# %run classify.py --model-name project2 --captcha-dir JORDANHU-project2rpi --output project2.csv --symbols symbols_with_space.txt
# Out:
# Classifying captchas with symbol set {!"#$%&()*+,/-:<=>?@[\]^ abcdefghijklmnopqrstuvwxyz|~}
# 0: Classified f4e05bfa6cf62894a3323abe686b358a17c293a7.png as )!][#
# 1: Classified 91449f86a10e562ee42bb7b3ad335e68f83a0676.png as lce~
# 2: Classified 056e1093a31be88587e6f829b23376abda297085.png as t
# 3: Classified 183cb211e0cbdd54860f4047160133dac45becdb.png as ?v
# 4: Classified 34c506eba56068af2001371861c4a05da615bcf4.png as g)i&
# 5: Classified 97024883aa76674b49ec6e8f41ee112a5338545f.png as tx
# 6: Classified 944c5f70fe2d311996c6fc9e6469f00a11081254.png as -#@@c~
# 7: Classified 4c0c338f66ff4d49007db6db7b04f71b065b78a3.png as t%v:z"
# 8: Classified 64ce6370009db55cdf21eeb8df40d5959cb6941f.png as vgz
# 9: Classified fa4602ca314a0ac55d7e6a6ebe6aaf6ca7e851b8.png as ^v>
# 10: Classified d4151de97b7cbeb09e9dddecb37e4574dff14d98.png as ti%$~
# 11: Classified 40ee02917e8f8fbae0e258d0dda05122b471ad9b.png as %%j
# 12: Classified 99f7d19ef382311fc6dfeccc1485a85812d280d8.png as l@#^!l
# ...
